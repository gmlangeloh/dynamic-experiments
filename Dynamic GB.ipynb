# %%
#How to use the current dynamic_gb implementation

load("benchmarks.sage")
load("dynamic-perry.spyx")

#Loading some common instances (cyclic family)
#Benchmark(I), for I some ideal previously loaded in Sage also works
c4 = Benchmark("./instances/cyclicn4.ideal") #The sensitivity analysis algorithm has problems with this instance!
c4h = Benchmark("./instances/cyclicnh4.ideal")
c5 = Benchmark("./instances/cyclicn5.ideal")
c5h = Benchmark("./instances/cyclicnh5.ideal")
c6 = Benchmark("./instances/cyclicn6.ideal")
c6h = Benchmark("./instances/cyclicnh6.ideal")
c7 = Benchmark("./instances/cyclicn7.ideal")
c7h = Benchmark("./instances/cyclicnh7.ideal")

#Using Perry's restricted dynamic algorithm from Caboara and Perry (2014)
_=dynamic_gb(c4.ideal.gens(), strategy="sugar")

#Using sensitivity analysis based algorithm
_=dynamic_gb(c4h.ideal.gens(), strategy="sugar", simplex=True)

#Optionally, we can use max_calls to switch to Perry's algorithm after a set number of iterations
_=dynamic_gb(c5.ideal.gens(), strategy="sugar", simplex=True, max_calls=10)

#Options static (classic Buchberger algorithm), unrestricted (Gritzmann-Sturmfels, 1993), 
#random and perturbation are also available - just set the corresponding parameters to true instead of simplex
# Out:
# -----------------------
# current ordering [1, 1, 1, 1]
# 4 critical pairs remaining
# 0 polynomials in basis
# current sugar 1
# building a
# new polynomial generated leading monomial with current ordering would be a
# [((0, 1, 0, 0), b), ((0, 0, 1, 0), c), ((0, 0, 0, 1), d), ((1, 0, 0, 0), a)]
# testing ((0, 1, 0, 0), b) against a
# obtaining ordering below 6.0
# 7 constraints
# b worked! with ((0, 1, 0, 0), [1.0, 2.0, 1.0, 1.0], Linear Program (minimization, 4 variables, 7 constraints))
# boundaries set([(0.01, 1.020000000745058, 0.01, 0.01), (0.26000000018626446, 0.27000000018626447, 0.2600000001862645, 0.26000000018626457), (0.510000000372529, 0.520000000372529, 0.01, 0.01), (0.01, 0.5200000003725291, 0.01, 0.510000000372529)])
# current ordering [1.0, 2.0, 1.0, 1.0]
# -----------------------
# current ordering [1.0, 2.0, 1.0, 1.0]
# 3 critical pairs remaining
# 1 polynomials in basis
# current sugar 2
# building b^2
# new polynomial generated leading monomial with current ordering would be a^2
# [((0, 0, 2, 0), c^2), ((2, 0, 0, 0), a^2)]
# testing ((0, 0, 2, 0), c^2) against a^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# 8 constraints
# c^2 worked! with ((0, 0, 2, 0), [1.0, 3.0, 2.0, 1.0], Linear Program (minimization, 4 variables, 8 constraints))
# boundaries set([(0.01, 1.0249999986588954, 0.01500000000000001, 0.01), (0.01, 0.5249999993294477, 0.5149999993294477, 0.01), (0.01, 0.5224999993294477, 0.01500000000000001, 0.5124999993294477), (0.34333333288629847, 0.3583333328862985, 0.3483333328862985, 0.01), (0.25874999966472384, 0.27374999966472385, 0.26374999966472384, 0.2637499996647239)])
# current ordering [1.0, 3.0, 2.0, 1.0]
# -----------------------
# current ordering [1.0, 3.0, 2.0, 1.0]
# 2 critical pairs remaining
# 2 polynomials in basis
# current sugar 3
# building b*c^2
# new polynomial generated leading monomial with current ordering would be a^2*c
# [((0, 0, 1, 2), c*d^2), ((1, 0, 0, 2), a*d^2), ((2, 0, 1, 0), a^2*c)]
# testing ((1, 0, 0, 2), a*d^2) against a^2*c
# a*d^2 did not work!
# testing ((0, 0, 1, 2), c*d^2) against a^2*c
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# 10 constraints
# c*d^2 worked! with ((0, 0, 1, 2), [1.0, 3.0, 2.0, 2.0], Linear Program (minimization, 4 variables, 10 constraints))
# boundaries set([(0.25875000074505805, 0.27875000074505807, 0.26875000074505806, 0.26875000074505806), (0.01, 0.5300000014901162, 0.5200000014901162, 0.015), (0.01, 1.0300000029802323, 0.02000000000000001, 0.015), (0.01, 0.5275000014901161, 0.02000000000000001, 0.5175000014901161)])
# current ordering [1.0, 3.0, 2.0, 2.0]
# -----------------------
# current ordering [1.0, 3.0, 2.0, 2.0]
# 2 critical pairs remaining
# 3 polynomials in basis
# current sugar 4
# building (c*d^2, c^2, c^2*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [1.0, 3.0, 2.0, 2.0]
# 1 critical pairs remaining
# 3 polynomials in basis
# current sugar 4
# building b*c*d^2
# new polynomial generated leading monomial with current ordering would be a^2*c*d
# [((2, 0, 0, 2), a^2*d^2), ((2, 0, 1, 1), a^2*c*d)]
# testing ((2, 0, 0, 2), a^2*d^2) against a^2*c*d
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# 11 constraints
# a^2*d^2 worked! with ((2, 0, 0, 2), [1.0, 4.0, 2.0, 3.0], Linear Program (minimization, 4 variables, 11 constraints))
# boundaries set([(0.01, 0.3733333338300388, 0.3533333338300388, 0.3633333338300388), (0.01, 1.0400000014901163, 0.02, 0.03000000000000002), (0.26000000037252907, 0.2900000003725291, 0.2700000003725291, 0.2800000003725291), (0.01, 0.5400000007450582, 0.02, 0.5300000007450582)])
# current ordering [1.0, 4.0, 2.0, 3.0]
# -----------------------
# current ordering [1.0, 4.0, 2.0, 3.0]
# 1 critical pairs remaining
# 4 polynomials in basis
# current sugar 5
# building (a^2*d^2, c*d^2, a^2*c*d^2)
# new polynomial generated leading monomial with current ordering would be a^4*c
# [((4, 0, 1, 0), a^4*c)]
# current ordering [1.0, 4.0, 2.0, 3.0]
# -----------------------
# current ordering [1.0, 4.0, 2.0, 3.0]
# 2 critical pairs remaining
# 5 polynomials in basis
# current sugar 6
# building (a^4*c, c^2, a^4*c^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [1.0, 4.0, 2.0, 3.0]
# 1 critical pairs remaining
# 5 polynomials in basis
# current sugar 7
# building (a^4*c, a^2*d^2, a^4*c*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# final order [1.0, 4.0, 2.0, 3.0]
# 8 s-polynomials considered (direct count) 5 polynomials in basis; 3 zero reductions
# there were at most 5 polynomials in the basis at any one time
# there are 21 monomials in the output basis
# 0 comparisons were eliminated by rejection
# 9 monomials were eliminated by hypercube vectors
# 6 linear programs were created (including copies)
# 1 failed systems and  1 rejections stored
# 11 constraints are in the linear program
# -----------------------
# current ordering [1, 1, 1, 1, 1]
# 4 critical pairs remaining
# 0 polynomials in basis
# current sugar 1
# building a
# new polynomial generated leading monomial with current ordering would be a
# current ordering [607, 300, 273, 514, 134]
# -----------------------
# current ordering [607, 300, 273, 514, 134]
# 3 critical pairs remaining
# 1 polynomials in basis
# current sugar 2
# building d^2
# new polynomial generated leading monomial with current ordering would be d^2
# current ordering [575, 569, 809, 386, 598]
# -----------------------
# current ordering [575, 569, 809, 386, 598]
# 2 critical pairs remaining
# 2 polynomials in basis
# current sugar 3
# building b*c^2
# new polynomial generated leading monomial with current ordering would be a^2*b
# current ordering [267.0, 693.0, 694.0, 694.0, 870.0]
# -----------------------
# current ordering [267.0, 693.0, 694.0, 694.0, 870.0]
# 2 critical pairs remaining
# 3 polynomials in basis
# current sugar 3
# building (d^3, d^2, d^3)
# new polynomial generated leading monomial with current ordering would be b^2*d
# current ordering [267.0, 693.0, 694.0, 694.0, 870.0]
# -----------------------
# current ordering [267.0, 693.0, 694.0, 694.0, 870.0]
# 2 critical pairs remaining
# 4 polynomials in basis
# current sugar 4
# building (b^2*d, d^2, b^2*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [267.0, 693.0, 694.0, 694.0, 870.0]
# 1 critical pairs remaining
# 4 polynomials in basis
# current sugar 4
# building e^4
# new polynomial generated leading monomial with current ordering would be e^4
# current ordering [267.0, 693.0, 694.0, 694.0, 870.0]
# final order [267.0, 693.0, 694.0, 694.0, 870.0]
# 6 s-polynomials considered (direct count) 4 polynomials in basis; 1 zero reductions
# there were at most 4 polynomials in the basis at any one time
# there are 15 monomials in the output basis
# 0 comparisons were eliminated by rejection
# 0 monomials were eliminated by hypercube vectors
# 1 linear programs were created (including copies)
# 0 failed systems and  0 rejections stored
# 5 constraints are in the linear program
# -----------------------
# current ordering [1, 1, 1, 1, 1]
# 5 critical pairs remaining
# 0 polynomials in basis
# current sugar 1
# building a
# new polynomial generated leading monomial with current ordering would be a
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 4 critical pairs remaining
# 1 polynomials in basis
# current sugar 2
# building b^2
# new polynomial generated leading monomial with current ordering would be a^2
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 3 critical pairs remaining
# 2 polynomials in basis
# current sugar 3
# building b*c*d
# new polynomial generated leading monomial with current ordering would be a*c*d
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 3 critical pairs remaining
# 3 polynomials in basis
# current sugar 4
# building (a*c*d, a^2, a^2*c*d)
# new polynomial generated leading monomial with current ordering would be a*d^2*e
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 4 critical pairs remaining
# 4 polynomials in basis
# current sugar 4
# building b*c*d^2
# new polynomial generated leading monomial with current ordering would be c^2*d^2
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 4 critical pairs remaining
# 5 polynomials in basis
# current sugar 5
# building b*c*d*e^2
# new polynomial generated leading monomial with current ordering would be c*d^2*e^2
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 5 critical pairs remaining
# 6 polynomials in basis
# current sugar 5
# building (a*d^2*e, a*c*d, a*c*d^2*e)
# new polynomial generated leading monomial with current ordering would be c*d^3*e
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 7 critical pairs remaining
# 7 polynomials in basis
# current sugar 5
# building (a*d^2*e, a^2, a^2*d^2*e)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 6 critical pairs remaining
# 7 polynomials in basis
# current sugar 5
# building (c^2*d^2, a*c*d, a*c^2*d^2)
# new polynomial generated leading monomial with current ordering would be a*c^4
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 7 critical pairs remaining
# 8 polynomials in basis
# current sugar 6
# building (c*d^2*e^2, c^2*d^2, c^2*d^2*e^2)
# new polynomial generated leading monomial with current ordering would be c^3*d*e^2
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 8 critical pairs remaining
# 9 polynomials in basis
# current sugar 6
# building (c*d^3*e, c*d^2*e^2, c*d^3*e^2)
# new polynomial generated leading monomial with current ordering would be c^4*d*e
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 10 critical pairs remaining
# 10 polynomials in basis
# current sugar 6
# building (c*d^2*e^2, a*d^2*e, a*c*d^2*e^2)
# new polynomial generated leading monomial with current ordering would be d^3*e^3
# [((1, 0, 3, 0, 2), a*c^3*e^2), ((0, 0, 4, 0, 2), c^4*e^2), ((1, 0, 2, 0, 3), a*c^2*e^3), ((0, 0, 2, 1, 3), c^2*d*e^3), ((1, 0, 0, 1, 4), a*d*e^4), ((0, 0, 0, 2, 4), d^2*e^4), ((0, 0, 3, 0, 3), c^3*e^3), ((1, 0, 1, 0, 4), a*c*e^4), ((0, 0, 1, 1, 4), c*d*e^4), ((0, 0, 2, 0, 4), c^2*e^4), ((1, 0, 0, 0, 5), a*e^5), ((0, 0, 0, 1, 5), d*e^5), ((0, 0, 1, 0, 5), c*e^5), ((0, 0, 0, 3, 3), d^3*e^3)]
# testing ((0, 0, 4, 0, 2), c^4*e^2) against d^3*e^3
# obtaining ordering below 7.0
# c^4*e^2 did not work!
# testing ((0, 0, 0, 2, 4), d^2*e^4) against d^3*e^3
# d^2*e^4 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 11 critical pairs remaining
# 11 polynomials in basis
# current sugar 6
# building (c*d^3*e, c^2*d^2, c^2*d^3*e)
# new polynomial generated leading monomial with current ordering would be c^5*d
# [((0, 0, 5, 0, 1), c^5*e), ((1, 0, 3, 0, 2), a*c^3*e^2), ((0, 0, 4, 0, 2), c^4*e^2), ((1, 0, 2, 0, 3), a*c^2*e^3), ((0, 0, 2, 1, 3), c^2*d*e^3), ((1, 0, 0, 1, 4), a*d*e^4), ((0, 0, 0, 2, 4), d^2*e^4), ((0, 0, 3, 0, 3), c^3*e^3), ((1, 0, 1, 0, 4), a*c*e^4), ((0, 0, 1, 1, 4), c*d*e^4), ((0, 0, 2, 0, 4), c^2*e^4), ((1, 0, 0, 0, 5), a*e^5), ((0, 0, 0, 1, 5), d*e^5), ((0, 0, 1, 0, 5), c*e^5), ((0, 0, 5, 1, 0), c^5*d)]
# testing ((0, 0, 5, 0, 1), c^5*e) against c^5*d
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c^5*e did not work!
# testing ((0, 0, 4, 0, 2), c^4*e^2) against c^5*d
# c^4*e^2 did not work!
# testing ((0, 0, 3, 0, 3), c^3*e^3) against c^5*d
# c^3*e^3 did not work!
# testing ((0, 0, 2, 0, 4), c^2*e^4) against c^5*d
# c^2*e^4 did not work!
# testing ((0, 0, 1, 0, 5), c*e^5) against c^5*d
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c*e^5 did not work!
# testing ((1, 0, 3, 0, 2), a*c^3*e^2) against c^5*d
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*c^3*e^2 did not work!
# testing ((0, 0, 2, 1, 3), c^2*d*e^3) against c^5*d
# c^2*d*e^3 did not work!
# testing ((1, 0, 0, 1, 4), a*d*e^4) against c^5*d
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d*e^4 did not work!
# testing ((0, 0, 0, 2, 4), d^2*e^4) against c^5*d
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# d^2*e^4 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 13 critical pairs remaining
# 12 polynomials in basis
# current sugar 6
# building (a*c^4, a*c*d, a*c^4*d)
# new polynomial generated leading monomial with current ordering would be d^4*e^2
# [((1, 0, 3, 0, 2), a*c^3*e^2), ((0, 0, 4, 0, 2), c^4*e^2), ((1, 0, 2, 0, 3), a*c^2*e^3), ((0, 0, 2, 1, 3), c^2*d*e^3), ((1, 0, 0, 1, 4), a*d*e^4), ((0, 0, 0, 2, 4), d^2*e^4), ((0, 0, 3, 0, 3), c^3*e^3), ((1, 0, 1, 0, 4), a*c*e^4), ((0, 0, 1, 1, 4), c*d*e^4), ((0, 0, 2, 0, 4), c^2*e^4), ((1, 0, 0, 0, 5), a*e^5), ((0, 0, 0, 1, 5), d*e^5), ((0, 0, 1, 0, 5), c*e^5), ((0, 0, 0, 4, 2), d^4*e^2)]
# testing ((0, 0, 4, 0, 2), c^4*e^2) against d^4*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c^4*e^2 did not work!
# testing ((0, 0, 3, 0, 3), c^3*e^3) against d^4*e^2
# c^3*e^3 did not work!
# testing ((0, 0, 2, 0, 4), c^2*e^4) against d^4*e^2
# c^2*e^4 did not work!
# testing ((0, 0, 1, 0, 5), c*e^5) against d^4*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c*e^5 did not work!
# testing ((1, 0, 3, 0, 2), a*c^3*e^2) against d^4*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*c^3*e^2 did not work!
# testing ((0, 0, 2, 1, 3), c^2*d*e^3) against d^4*e^2
# c^2*d*e^3 did not work!
# testing ((1, 0, 0, 1, 4), a*d*e^4) against d^4*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d*e^4 did not work!
# testing ((0, 0, 0, 2, 4), d^2*e^4) against d^4*e^2
# d^2*e^4 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 15 critical pairs remaining
# 13 polynomials in basis
# current sugar 6
# building (a*c^4, a^2, a^2*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 14 critical pairs remaining
# 13 polynomials in basis
# current sugar 6
# building (c*d^3*e, a*d^2*e, a*c*d^3*e)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 13 critical pairs remaining
# 13 polynomials in basis
# current sugar 7
# building (c^4*d*e, c^3*d*e^2, c^4*d*e^2)
# new polynomial generated leading monomial with current ordering would be a*c^3*e^3
# [((0, 0, 4, 0, 3), c^4*e^3), ((1, 0, 2, 0, 4), a*c^2*e^4), ((0, 0, 2, 1, 4), c^2*d*e^4), ((1, 0, 0, 1, 5), a*d*e^5), ((0, 0, 0, 2, 5), d^2*e^5), ((0, 0, 3, 0, 4), c^3*e^4), ((1, 0, 1, 0, 5), a*c*e^5), ((0, 0, 1, 1, 5), c*d*e^5), ((0, 0, 2, 0, 5), c^2*e^5), ((1, 0, 0, 0, 6), a*e^6), ((0, 0, 0, 1, 6), d*e^6), ((0, 0, 1, 0, 6), c*e^6), ((1, 0, 3, 0, 3), a*c^3*e^3)]
# testing ((0, 0, 4, 0, 3), c^4*e^3) against a*c^3*e^3
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c^4*e^3 did not work!
# testing ((0, 0, 3, 0, 4), c^3*e^4) against a*c^3*e^3
# c^3*e^4 did not work!
# testing ((0, 0, 2, 0, 5), c^2*e^5) against a*c^3*e^3
# c^2*e^5 did not work!
# testing ((0, 0, 1, 0, 6), c*e^6) against a*c^3*e^3
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c*e^6 did not work!
# testing ((0, 0, 2, 1, 4), c^2*d*e^4) against a*c^3*e^3
# c^2*d*e^4 did not work!
# testing ((1, 0, 0, 1, 5), a*d*e^5) against a*c^3*e^3
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d*e^5 did not work!
# testing ((0, 0, 0, 2, 5), d^2*e^5) against a*c^3*e^3
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# d^2*e^5 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 15 critical pairs remaining
# 14 polynomials in basis
# current sugar 7
# building (d^3*e^3, c*d^3*e, c*d^3*e^3)
# new polynomial generated leading monomial with current ordering would be c^4*e^3
# [((1, 0, 2, 0, 4), a*c^2*e^4), ((0, 0, 2, 1, 4), c^2*d*e^4), ((1, 0, 0, 1, 5), a*d*e^5), ((0, 0, 0, 2, 5), d^2*e^5), ((0, 0, 3, 0, 4), c^3*e^4), ((1, 0, 1, 0, 5), a*c*e^5), ((0, 0, 1, 1, 5), c*d*e^5), ((0, 0, 2, 0, 5), c^2*e^5), ((1, 0, 0, 0, 6), a*e^6), ((0, 0, 0, 1, 6), d*e^6), ((0, 0, 1, 0, 6), c*e^6), ((0, 0, 4, 0, 3), c^4*e^3)]
# testing ((0, 0, 3, 0, 4), c^3*e^4) against c^4*e^3
# c^3*e^4 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 16 critical pairs remaining
# 15 polynomials in basis
# current sugar 7
# building (c^3*d*e^2, c*d^2*e^2, c^3*d^2*e^2)
# new polynomial generated leading monomial with current ordering would be a*c^2*e^4
# [((0, 0, 2, 1, 4), c^2*d*e^4), ((1, 0, 0, 1, 5), a*d*e^5), ((0, 0, 0, 2, 5), d^2*e^5), ((0, 0, 3, 0, 4), c^3*e^4), ((1, 0, 1, 0, 5), a*c*e^5), ((0, 0, 1, 1, 5), c*d*e^5), ((0, 0, 2, 0, 5), c^2*e^5), ((1, 0, 0, 0, 6), a*e^6), ((0, 0, 0, 1, 6), d*e^6), ((0, 0, 1, 0, 6), c*e^6), ((1, 0, 2, 0, 4), a*c^2*e^4)]
# testing ((0, 0, 2, 1, 4), c^2*d*e^4) against a*c^2*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c^2*d*e^4 did not work!
# testing ((1, 0, 0, 1, 5), a*d*e^5) against a*c^2*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d*e^5 did not work!
# testing ((0, 0, 0, 2, 5), d^2*e^5) against a*c^2*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# d^2*e^5 did not work!
# testing ((0, 0, 3, 0, 4), c^3*e^4) against a*c^2*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c^3*e^4 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 18 critical pairs remaining
# 16 polynomials in basis
# current sugar 7
# building (c^3*d*e^2, a*c*d, a*c^3*d*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 17 critical pairs remaining
# 16 polynomials in basis
# current sugar 7
# building (c^5*d, c^4*d*e, c^5*d*e)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 16 critical pairs remaining
# 16 polynomials in basis
# current sugar 7
# building (d^4*e^2, d^3*e^3, d^4*e^3)
# new polynomial generated leading monomial with current ordering would be c^2*d*e^4
# [((1, 0, 0, 1, 5), a*d*e^5), ((0, 0, 0, 2, 5), d^2*e^5), ((0, 0, 3, 0, 4), c^3*e^4), ((1, 0, 1, 0, 5), a*c*e^5), ((0, 0, 1, 1, 5), c*d*e^5), ((0, 0, 2, 0, 5), c^2*e^5), ((1, 0, 0, 0, 6), a*e^6), ((0, 0, 0, 1, 6), d*e^6), ((0, 0, 1, 0, 6), c*e^6), ((0, 0, 2, 1, 4), c^2*d*e^4)]
# testing ((1, 0, 0, 1, 5), a*d*e^5) against c^2*d*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d*e^5 did not work!
# testing ((0, 0, 0, 2, 5), d^2*e^5) against c^2*d*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# d^2*e^5 did not work!
# testing ((0, 0, 3, 0, 4), c^3*e^4) against c^2*d*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# c^3*e^4 did not work!
# testing ((1, 0, 1, 0, 5), a*c*e^5) against c^2*d*e^4
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*c*e^5 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 18 critical pairs remaining
# 17 polynomials in basis
# current sugar 7
# building (d^3*e^3, a*d^2*e, a*d^3*e^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 17 critical pairs remaining
# 17 polynomials in basis
# current sugar 7
# building (c^4*d*e, c^2*d^2, c^4*d^2*e)
# new polynomial generated leading monomial with current ordering would be a*d*e^5
# [((0, 0, 0, 2, 5), d^2*e^5), ((1, 0, 1, 0, 5), a*c*e^5), ((0, 0, 2, 0, 5), c^2*e^5), ((0, 0, 0, 1, 6), d*e^6), ((0, 0, 1, 0, 6), c*e^6), ((1, 0, 0, 1, 5), a*d*e^5)]
# testing ((0, 0, 0, 2, 5), d^2*e^5) against a*d*e^5
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# d^2*e^5 did not work!
# testing ((1, 0, 1, 0, 5), a*c*e^5) against a*d*e^5
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*c*e^5 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 19 critical pairs remaining
# 18 polynomials in basis
# current sugar 7
# building (c^4*d*e, a*c^4, a*c^4*d*e)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 18 critical pairs remaining
# 18 polynomials in basis
# current sugar 7
# building (d^4*e^2, c*d^3*e, c*d^4*e^2)
# new polynomial generated leading monomial with current ordering would be c^5*e^2
# [((0, 0, 0, 2, 5), d^2*e^5), ((0, 0, 3, 0, 4), c^3*e^4), ((1, 0, 1, 0, 5), a*c*e^5), ((0, 0, 1, 1, 5), c*d*e^5), ((0, 0, 2, 0, 5), c^2*e^5), ((1, 0, 0, 0, 6), a*e^6), ((0, 0, 0, 1, 6), d*e^6), ((1, 0, 0, 1, 0), a*d), ((0, 0, 1, 0, 6), c*e^6), ((0, 0, 5, 0, 2), c^5*e^2)]
# testing ((1, 0, 0, 1, 0), a*d) against c^5*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d did not work!
# testing ((0, 0, 0, 2, 5), d^2*e^5) against c^5*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# d^2*e^5 did not work!
# testing ((0, 0, 3, 0, 4), c^3*e^4) against c^5*e^2
# c^3*e^4 did not work!
# testing ((1, 0, 1, 0, 5), a*c*e^5) against c^5*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*c*e^5 did not work!
# testing ((0, 0, 1, 1, 5), c*d*e^5) against c^5*e^2
# c*d*e^5 did not work!
# current ordering [389, 653, 245, 387, 78]
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 20 critical pairs remaining
# 19 polynomials in basis
# current sugar 7
# building (c^5*d, c^2*d^2, c^5*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 19 critical pairs remaining
# 19 polynomials in basis
# current sugar 7
# building (c^5*d, a*c^4, a*c^5*d)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 18 critical pairs remaining
# 19 polynomials in basis
# current sugar 7
# building (d^4*e^2, a*d^2*e, a*d^4*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [389, 653, 245, 387, 78]
# 17 critical pairs remaining
# 19 polynomials in basis
# current sugar 8
# building (a*d*e^5, a*c*d, a*c*d*e^5)
# new polynomial generated leading monomial with current ordering would be d^2*e^6
# [((0, 0, 3, 0, 5), c^3*e^5), ((1, 0, 1, 0, 6), a*c*e^6), ((0, 0, 1, 1, 6), c*d*e^6), ((0, 0, 1, 2, 0), c*d^2), ((0, 0, 2, 0, 6), c^2*e^6), ((1, 0, 0, 0, 7), a*e^7), ((0, 0, 0, 1, 7), d*e^7), ((0, 0, 2, 1, 0), c^2*d), ((1, 0, 0, 1, 1), a*d*e), ((0, 0, 1, 0, 7), c*e^7), ((0, 0, 0, 2, 6), d^2*e^6)]
# testing ((0, 0, 2, 1, 0), c^2*d) against d^2*e^6
# c^2*d did not work!
# testing ((1, 0, 0, 1, 1), a*d*e) against d^2*e^6
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a*d*e did not work!
# testing ((0, 0, 1, 2, 0), c*d^2) against d^2*e^6
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# obtaining ordering below 101.0
# 20 constraints
# c*d^2 worked! with ((0, 0, 1, 2, 0), [12.0, 13.0, 7.0, 11.0, 1.0], Linear Program (minimization, 5 variables, 20 constraints))
# boundaries set([(0.19999999999999982, 0.9950000119209288, 0.06999999999999995, 0.14999999999999986, 0.01), (0.3877272759784351, 0.3977272759784351, 0.25181818398562344, 0.37772727597843514, 0.01), (0.13999999999999996, 1.1000000119209292, 0.06999999999999999, 0.105, 0.01), (0.37653846465624285, 0.38653846465624286, 0.2546153868161714, 0.36653846465624285, 0.04076923113602857), (0.11499999999999998, 1.1250000119209287, 0.06999999999999999, 0.10499999999999998, 0.01)])
# current ordering [12.0, 13.0, 7.0, 11.0, 1.0]
# -----------------------
# current ordering [12.0, 13.0, 7.0, 11.0, 1.0]
# 20 critical pairs remaining
# 20 polynomials in basis
# current sugar 8
# building (c^2*d*e^4, c^3*d*e^2, c^3*d*e^4)
# new polynomial generated leading monomial with current ordering would be d^2*e^6
# [((1, 0, 2, 0, 0), a*c^2), ((0, 0, 2, 1, 0), c^2*d), ((0, 0, 0, 2, 6), d^2*e^6)]
# testing ((1, 0, 2, 0, 0), a*c^2) against d^2*e^6
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# obtaining ordering below 101.0
# 24 constraints
# a*c^2 worked! with ((1, 0, 2, 0, 0), [21.0, 22.0, 12.0, 19.0, 1.0], Linear Program (minimization, 5 variables, 24 constraints))
# boundaries set([(0.5009090936834161, 0.5109090936834161, 0.2695454560193148, 0.4304545477953823, 0.028181818355213516), (0.4686666692097978, 0.47866666920979783, 0.30783333508173605, 0.4586666692097979, 0.02616666682561239), (0.2099999999999999, 1.2200000095367434, 0.11499999999999994, 0.1849999999999999, 0.01), (0.510000002861023, 0.520000002861023, 0.2650000014305115, 0.43500000238418585, 0.01), (0.2099999999999998, 1.1900000095367431, 0.12999999999999992, 0.19999999999999984, 0.01)])
# current ordering [21.0, 22.0, 12.0, 19.0, 1.0]
# -----------------------
# current ordering [21.0, 22.0, 12.0, 19.0, 1.0]
# 18 critical pairs remaining
# 21 polynomials in basis
# current sugar 8
# building (c^5*e^2, c^4*e^3, c^5*e^3)
# new polynomial generated leading monomial with current ordering would be d^2*e^6
# [((0, 0, 2, 1, 0), c^2*d), ((1, 0, 0, 1, 1), a*d*e), ((0, 0, 0, 2, 6), d^2*e^6)]
# testing ((0, 0, 2, 1, 0), c^2*d) against d^2*e^6
# obtaining ordering below 2.0
# failed
# obtaining ordering below 102.0
# 25 constraints
# c^2*d worked! with ((0, 0, 2, 1, 0), [24.0, 25.0, 15.0, 23.0, 1.0], Linear Program (minimization, 5 variables, 25 constraints))
# boundaries set([(0.5127272714268077, 0.5227272714268077, 0.3318181809512051, 0.5027272714268077, 0.01), (0.5066666653951007, 0.5166666653951008, 0.33333333245913177, 0.49666666539510074, 0.026666666587193792), (0.24000000000000016, 1.2499999952316276, 0.1500000000000001, 0.23000000000000018, 0.01), (0.24000000000000016, 1.2499999952316276, 0.15000000000000013, 0.2300000000000002, 0.01)])
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 22 critical pairs remaining
# 22 polynomials in basis
# current sugar 8
# building (a*d*e^5, a*d^2*e, a*d^2*e^5)
# new polynomial generated leading monomial with current ordering would be a*d^2
# [((1, 0, 0, 2, 0), a*d^2)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 24 critical pairs remaining
# 23 polynomials in basis
# current sugar 8
# building (a*d*e^5, a^2, a^2*d*e^5)
# new polynomial generated leading monomial with current ordering would be d^3
# [((0, 0, 0, 3, 0), d^3)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 27 critical pairs remaining
# 24 polynomials in basis
# current sugar 8
# building (c^2*d*e^4, a*c^2*e^4, a*c^2*d*e^4)
# new polynomial generated leading monomial with current ordering would be c^3*e^5
# [((0, 0, 3, 0, 5), c^3*e^5)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 29 critical pairs remaining
# 25 polynomials in basis
# current sugar 8
# building (c^4*e^3, c^4*d*e, c^4*d*e^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 28 critical pairs remaining
# 25 polynomials in basis
# current sugar 8
# building (c^4*e^3, a*c^3*e^3, a*c^4*e^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 27 critical pairs remaining
# 25 polynomials in basis
# current sugar 8
# building (c^5*e^2, c^5*d, c^5*d*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 26 critical pairs remaining
# 25 polynomials in basis
# current sugar 8
# building (c^5*e^2, a*c^4, a*c^5*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 25 critical pairs remaining
# 25 polynomials in basis
# current sugar 9
# building (c^3*e^5, c^4*e^3, c^4*e^5)
# new polynomial generated leading monomial with current ordering would be c^4
# [((0, 0, 4, 0, 0), c^4)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 28 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (a*d^2, a*d^2*e, a*d^2*e)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 27 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (c*d^2, c^2*d^2, c^2*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 26 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (c^2*d, c*d^2, c^2*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 25 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (a*c^2, a*c*d, a*c^2*d)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 24 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (c^2*d, a*c^2, a*c^2*d)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 23 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (a*c^2, a^2, a^2*c^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 22 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (d^3, c*d^2, c*d^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 21 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (c*d^2, a*c*d, a*c*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 20 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (a*d^2, c*d^2, a*c*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 19 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (d^3, a*d^2, a*d^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 18 critical pairs remaining
# 26 polynomials in basis
# current sugar 9
# building (a*d^2, a^2, a^2*d^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 26 polynomials in basis
# current sugar 10
# building (c*d^2, c*d^2*e^2, c*d^2*e^2)
# new polynomial generated leading monomial with current ordering would be d^2*e^8
# [((0, 0, 0, 2, 8), d^2*e^8)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 19 critical pairs remaining
# 27 polynomials in basis
# current sugar 10
# building (c^4, c^2*d, c^4*d)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 18 critical pairs remaining
# 27 polynomials in basis
# current sugar 10
# building (a*c^2, a*c^4, a*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 27 polynomials in basis
# current sugar 10
# building (c^4, a*c^2, a*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 16 critical pairs remaining
# 27 polynomials in basis
# current sugar 10
# building (c*d^2, c*d^3*e, c*d^3*e)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 15 critical pairs remaining
# 27 polynomials in basis
# current sugar 11
# building (c^2*d, c^3*d*e^2, c^3*d*e^2)
# new polynomial generated leading monomial with current ordering would be a*c*e^9
# [((1, 0, 1, 0, 9), a*c*e^9)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 28 polynomials in basis
# current sugar 11
# building (d^3, d^3*e^3, d^3*e^3)
# new polynomial generated leading monomial with current ordering would be a*e^5
# [((1, 0, 0, 0, 5), a*e^5)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 29 polynomials in basis
# current sugar 11
# building (c^2*d, c^4*d*e, c^4*d*e)
# new polynomial generated leading monomial with current ordering would be c*d*e^9
# [((0, 0, 1, 1, 9), c*d*e^9)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 19 critical pairs remaining
# 30 polynomials in basis
# current sugar 11
# building (d^3, d^4*e^2, d^4*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 18 critical pairs remaining
# 30 polynomials in basis
# current sugar 11
# building (c^2*d, c^5*d, c^5*d)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 30 polynomials in basis
# current sugar 12
# building (a*e^5, a*d*e^5, a*d*e^5)
# new polynomial generated leading monomial with current ordering would be d^2*e^5
# [((0, 0, 0, 2, 5), d^2*e^5)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 31 polynomials in basis
# current sugar 12
# building (a*e^5, a^2, a^2*e^5)
# new polynomial generated leading monomial with current ordering would be c^2*e^5
# [((0, 0, 2, 0, 5), c^2*e^5)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 32 polynomials in basis
# current sugar 12
# building (c^2*d, c^2*d*e^4, c^2*d*e^4)
# new polynomial generated leading monomial with current ordering would be c*d*e^5
# [((0, 0, 1, 1, 5), c*d*e^5)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 17 critical pairs remaining
# 33 polynomials in basis
# current sugar 12
# building (a*c^2, a*c^2*e^4, a*c^2*e^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 16 critical pairs remaining
# 33 polynomials in basis
# current sugar 12
# building (c^4, c^4*e^3, c^4*e^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 15 critical pairs remaining
# 33 polynomials in basis
# current sugar 12
# building (a*c^2, a*c^3*e^3, a*c^3*e^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 14 critical pairs remaining
# 33 polynomials in basis
# current sugar 12
# building (c^4, c^5*e^2, c^5*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 13 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (c^2*e^5, c^3*e^5, c^3*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 12 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (c^2*e^5, c^2*d, c^2*d*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 11 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (a*e^5, a*c^2, a*c^2*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 10 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (c^2*e^5, a*e^5, a*c^2*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 9 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (d^2*e^5, c*d^2, c*d^2*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 8 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (d^2*e^5, d^3, d^3*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 7 critical pairs remaining
# 33 polynomials in basis
# current sugar 13
# building (d^2*e^5, a*e^5, a*d^2*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 6 critical pairs remaining
# 33 polynomials in basis
# current sugar 15
# building (d^2*e^5, d^2*e^8, d^2*e^8)
# new polynomial generated leading monomial with current ordering would be c*e^9
# [((0, 0, 1, 0, 9), c*e^9)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 8 critical pairs remaining
# 34 polynomials in basis
# current sugar 16
# building (c*e^9, c^2*e^5, c^2*e^9)
# new polynomial generated leading monomial with current ordering would be c*e^5
# [((0, 0, 1, 0, 5), c*e^5)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 7 critical pairs remaining
# 35 polynomials in basis
# current sugar 16
# building (a*e^5, a*c*e^9, a*c*e^9)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 6 critical pairs remaining
# 35 polynomials in basis
# current sugar 17
# building (c*e^5, c^2*e^5, c^2*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 5 critical pairs remaining
# 35 polynomials in basis
# current sugar 17
# building (c*e^5, c*d*e^5, c*d*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 4 critical pairs remaining
# 35 polynomials in basis
# current sugar 17
# building (c*e^5, a*e^5, a*c*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 3 critical pairs remaining
# 35 polynomials in basis
# current sugar 18
# building (c*d*e^5, d^2*e^5, c*d^2*e^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 2 critical pairs remaining
# 35 polynomials in basis
# current sugar 20
# building (c*e^5, c*e^9, c*e^9)
# new polynomial generated leading monomial with current ordering would be e^15
# [((0, 0, 0, 0, 15), e^15)]
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 4 critical pairs remaining
# 36 polynomials in basis
# current sugar 21
# building (e^15, a*e^5, a*e^15)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 3 critical pairs remaining
# 36 polynomials in basis
# current sugar 21
# building (c*d*e^5, c*d*e^9, c*d*e^9)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 2 critical pairs remaining
# 36 polynomials in basis
# current sugar 22
# building (e^15, d^2*e^5, d^2*e^15)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [24.0, 25.0, 15.0, 23.0, 1.0]
# 1 critical pairs remaining
# 36 polynomials in basis
# current sugar 26
# building (e^15, c*e^5, c*e^15)
# new polynomial generated leading monomial with current ordering would be 0
# final order [24.0, 25.0, 15.0, 23.0, 1.0]
# 87 s-polynomials considered (direct count) 13 polynomials in basis; 51 zero reductions
# there were at most 36 polynomials in the basis at any one time
# there are 124 monomials in the output basis
# 7 comparisons were eliminated by rejection
# 183 monomials were eliminated by hypercube vectors
# 48 linear programs were created (including copies)
# 37 failed systems and  37 rejections stored
# 25 constraints are in the linear program

# %%
#Trying a different, harder instance

load("benchmarks.sage")
load("dynamic-perry.spyx")

j210 = Benchmark("./instances/jason210.ideal")

_=dynamic_gb(j210.ideal.gens(), strategy="sugar", simplex=True, max_calls=20)
# Out:
# -----------------------
# current ordering [1, 1, 1, 1, 1, 1, 1, 1]
# 3 critical pairs remaining
# 0 polynomials in basis
# current sugar 6
# building a^2*c^4
# new polynomial generated leading monomial with current ordering would be a^2*c^4
# current ordering [694, 109, 612, 189, 82, 309, 199, 984]
# -----------------------
# current ordering [694, 109, 612, 189, 82, 309, 199, 984]
# 2 critical pairs remaining
# 1 polynomials in basis
# current sugar 6
# building b^6
# new polynomial generated leading monomial with current ordering would be b^6
# current ordering [334, 766, 658, 163, 140, 257, 967, 232]
# -----------------------
# current ordering [334, 766, 658, 163, 140, 257, 967, 232]
# 1 critical pairs remaining
# 2 polynomials in basis
# current sugar 6
# building a^6
# new polynomial generated leading monomial with current ordering would be a^6
# current ordering [256, 302, 464, 109, 73, 345, 928, 263]
# -----------------------
# current ordering [256, 302, 464, 109, 73, 345, 928, 263]
# 1 critical pairs remaining
# 3 polynomials in basis
# current sugar 10
# building (a^6, a^2*c^4, a^6*c^4)
# new polynomial generated leading monomial with current ordering would be a^5*b*c*d*e*g
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# -----------------------
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# 2 critical pairs remaining
# 4 polynomials in basis
# current sugar 10
# building (a^5*b*d^2*f^2, a*b*d^2*f^2, a^5*b*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# 1 critical pairs remaining
# 4 polynomials in basis
# current sugar 11
# building (b^6, a*b*d^2*f^2, a*b^6*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be a^2*b^5*c^4
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# -----------------------
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# 3 critical pairs remaining
# 5 polynomials in basis
# current sugar 12
# building (a^2*b^5*c^4, b^6, a^2*b^6*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# 2 critical pairs remaining
# 5 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^4, a^6, a^6*b^5*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [315, 19, 289, 425, 413, 725, 972, 296]
# 1 critical pairs remaining
# 5 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^4, a*b*d^2*f^2, a^2*b^5*c^4*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be a^3*b^4*c^8
# current ordering [401, 274, 190, 656, 238, 798, 653, 997]
# -----------------------
# current ordering [401, 274, 190, 656, 238, 798, 653, 997]
# 3 critical pairs remaining
# 6 polynomials in basis
# current sugar 16
# building (a^3*b^4*c^8, a^2*b^5*c^4, a^3*b^5*c^8)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [401, 274, 190, 656, 238, 798, 653, 997]
# 2 critical pairs remaining
# 6 polynomials in basis
# current sugar 18
# building (a^3*b^4*c^8, a^6, a^6*b^4*c^8)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [401, 274, 190, 656, 238, 798, 653, 997]
# 1 critical pairs remaining
# 6 polynomials in basis
# current sugar 19
# building (a^3*b^4*c^8, a*b*d^2*f^2, a^3*b^4*c^8*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be a^4*b^3*c^12
# current ordering [419, 719, 280, 113, 231, 751, 716, 807]
# -----------------------
# current ordering [419, 719, 280, 113, 231, 751, 716, 807]
# 9 critical pairs remaining
# 7 polynomials in basis
# current sugar 10
# building (a^5*b*c*d*f*h, a*b*c*d*f*h, a^5*b*c*d*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [419, 719, 280, 113, 231, 751, 716, 807]
# 8 critical pairs remaining
# 7 polynomials in basis
# current sugar 11
# building (a^6, a*b*c*d*f*h, a^6*b*c*d*f*h)
# new polynomial generated leading monomial with current ordering would be a^5*b^2*d^4
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 13 critical pairs remaining
# 8 polynomials in basis
# current sugar 11
# building (b^6, a*b*c*d*f*h, a*b^6*c*d*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 12 critical pairs remaining
# 8 polynomials in basis
# current sugar 12
# building (a^2*b^5*c^4, b^6, a^2*b^6*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 11 critical pairs remaining
# 8 polynomials in basis
# current sugar 12
# building (a^5*b^2*d^4, a^6, a^6*b^2*d^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 10 critical pairs remaining
# 8 polynomials in basis
# current sugar 14
# building (a^2*b^5*c^4, a*b*c*d*f*h, a^2*b^5*c^4*d*f*h)
# new polynomial generated leading monomial with current ordering would be a^2*b^5*c^3*d^2*f^2
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 14 critical pairs remaining
# 9 polynomials in basis
# current sugar 14
# building (a^5*b^2*d^4, a^5*b*c*d*f*h, a^5*b^2*c*d^4*f*h)
# new polynomial generated leading monomial with current ordering would be a^4*b^3*d^7
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 20 critical pairs remaining
# 10 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^4, a^6, a^6*b^5*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 19 critical pairs remaining
# 10 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^3*d^2*f^2, a^2*b^5*c^4, a^2*b^5*c^4*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 18 critical pairs remaining
# 10 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^3*d^2*f^2, b^6, a^2*b^6*c^3*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 17 critical pairs remaining
# 10 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^3*d^2*f^2, a*b*c*d*f*h, a^2*b^5*c^3*d^2*f^2*h)
# new polynomial generated leading monomial with current ordering would be a^2*b^5*c^2*d^3*f^3
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 22 critical pairs remaining
# 11 polynomials in basis
# current sugar 15
# building (a^5*b^2*d^4, b^6, a^5*b^6*d^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 21 critical pairs remaining
# 11 polynomials in basis
# current sugar 15
# building (a^4*b^3*d^7, a^5*b^2*d^4, a^5*b^3*d^7)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 20 critical pairs remaining
# 11 polynomials in basis
# current sugar 16
# building (a^2*b^5*c^2*d^3*f^3, a^2*b^5*c^3*d^2*f^2, a^2*b^5*c^3*d^3*f^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 19 critical pairs remaining
# 11 polynomials in basis
# current sugar 16
# building (a^2*b^5*c^2*d^3*f^3, b^6, a^2*b^6*c^2*d^3*f^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 18 critical pairs remaining
# 11 polynomials in basis
# current sugar 16
# building (a^2*b^5*c^2*d^3*f^3, a*b*c*d*f*h, a^2*b^5*c^2*d^3*f^3*h)
# new polynomial generated leading monomial with current ordering would be a^2*b^5*c*d^4*f^4
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 22 critical pairs remaining
# 12 polynomials in basis
# current sugar 17
# building (a^2*b^5*c*d^4*f^4, a^2*b^5*c^2*d^3*f^3, a^2*b^5*c^2*d^4*f^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 21 critical pairs remaining
# 12 polynomials in basis
# current sugar 17
# building (a^4*b^3*d^7, b^6, a^4*b^6*d^7)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^2*d^3*e^2
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 27 critical pairs remaining
# 13 polynomials in basis
# current sugar 17
# building (a^2*b^5*c*d^4*f^4, b^6, a^2*b^6*c*d^4*f^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [512, 445, 307, 560, 157, 623, 778, 882]
# 26 critical pairs remaining
# 13 polynomials in basis
# current sugar 17
# building (a^4*b^3*d^7, a*b*c*d*f*h, a^4*b^3*c*d^7*f*h)
# new polynomial generated leading monomial with current ordering would be a^3*b^4*d^10
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 32 critical pairs remaining
# 14 polynomials in basis
# current sugar 10
# building (a^5*b*d^2*f^2, a*b*d^2*f^2, a^5*b*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 31 critical pairs remaining
# 14 polynomials in basis
# current sugar 11
# building (b^6, a*b*d^2*f^2, a*b^6*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 30 critical pairs remaining
# 14 polynomials in basis
# current sugar 11
# building (a^6, a*b*d^2*f^2, a^6*b*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 29 critical pairs remaining
# 14 polynomials in basis
# current sugar 12
# building (a^2*b^5*c^4, b^6, a^2*b^6*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 28 critical pairs remaining
# 14 polynomials in basis
# current sugar 12
# building (a^5*b^2*d^4, a^6, a^6*b^2*d^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 27 critical pairs remaining
# 14 polynomials in basis
# current sugar 13
# building (a^5*b^2*d^4, a^5*b*d^2*f^2, a^5*b^2*d^4*f^2)
# new polynomial generated leading monomial with current ordering would be a^4*b^3*d^6
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 27 critical pairs remaining
# 15 polynomials in basis
# current sugar 14
# building (a^2*b^5*c^3*d^2*f^2, a*b*d^2*f^2, a^2*b^5*c^3*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 26 critical pairs remaining
# 15 polynomials in basis
# current sugar 14
# building (a^4*b^3*d^6, a^5*b^2*d^4, a^5*b^3*d^6)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 25 critical pairs remaining
# 15 polynomials in basis
# current sugar 14
# building (a^4*b^3*d^6, a^4*b^3*d^7, a^4*b^3*d^7)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 24 critical pairs remaining
# 15 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^4, a^6, a^6*b^5*c^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 23 critical pairs remaining
# 15 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^4, a*b*d^2*f^2, a^2*b^5*c^4*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 22 critical pairs remaining
# 15 polynomials in basis
# current sugar 15
# building (a^2*b^5*c^2*d^3*f^3, a*b*d^2*f^2, a^2*b^5*c^2*d^3*f^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 21 critical pairs remaining
# 15 polynomials in basis
# current sugar 15
# building (a^5*b^2*d^4, b^6, a^5*b^6*d^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 20 critical pairs remaining
# 15 polynomials in basis
# current sugar 15
# building (a^4*b^3*d^6, a*b*d^2*f^2, a^4*b^3*d^6*f^2)
# new polynomial generated leading monomial with current ordering would be a^3*b^4*d^8
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 20 critical pairs remaining
# 16 polynomials in basis
# current sugar 16
# building (a^3*b^4*c^8, a^2*b^5*c^4, a^3*b^5*c^8)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 19 critical pairs remaining
# 16 polynomials in basis
# current sugar 16
# building (a^2*b^5*c*d^4*f^4, a*b*d^2*f^2, a^2*b^5*c*d^4*f^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 18 critical pairs remaining
# 16 polynomials in basis
# current sugar 16
# building (a^4*b^3*d^6, b^6, a^4*b^6*d^6)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c*d^3*e*g
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 23 critical pairs remaining
# 17 polynomials in basis
# current sugar 16
# building (a^3*b^4*d^8, a^4*b^3*d^6, a^4*b^4*d^8)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 22 critical pairs remaining
# 17 polynomials in basis
# current sugar 17
# building (a^5*b^5*c*d^3*e*g, b^6, a^5*b^6*c*d^3*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 21 critical pairs remaining
# 17 polynomials in basis
# current sugar 17
# building (a^5*b^5*c*d^3*e*g, a^6, a^6*b^5*c*d^3*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 20 critical pairs remaining
# 17 polynomials in basis
# current sugar 17
# building (a^5*b^5*c*d^3*e*g, a^5*b^2*d^4, a^5*b^5*c*d^4*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 19 critical pairs remaining
# 17 polynomials in basis
# current sugar 17
# building (a^3*b^4*d^8, b^6, a^3*b^6*d^8)
# new polynomial generated leading monomial with current ordering would be a^4*b^5*c*d^5*e*g
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 23 critical pairs remaining
# 18 polynomials in basis
# current sugar 17
# building (a^3*b^4*d^8, a^3*b^4*d^10, a^3*b^4*d^10)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 22 critical pairs remaining
# 18 polynomials in basis
# current sugar 17
# building (a^3*b^4*d^8, a*b*d^2*f^2, a^3*b^4*d^8*f^2)
# new polynomial generated leading monomial with current ordering would be a^2*b^5*d^10
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 25 critical pairs remaining
# 19 polynomials in basis
# current sugar 18
# building (a^3*b^4*c^8, a^6, a^6*b^4*c^8)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 24 critical pairs remaining
# 19 polynomials in basis
# current sugar 18
# building (a^5*b^2*d^4, a^2*b^5*c^4, a^5*b^5*c^4*d^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 23 critical pairs remaining
# 19 polynomials in basis
# current sugar 18
# building (a^5*b^5*c*d^3*e*g, a^5*b^5*c^2*d^3*e^2, a^5*b^5*c^2*d^3*e^2*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^2*d^3*e*f*h
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 29 critical pairs remaining
# 20 polynomials in basis
# current sugar 18
# building (a^4*b^5*c*d^5*e*g, b^6, a^4*b^6*c*d^5*e*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^2*d^2*e^2*g^2
# [((5, 5, 2, 2, 1, 1, 1, 1), a^5*b^5*c^2*d^2*e*f*g*h), ((5, 5, 3, 1, 3, 0, 1, 0), a^5*b^5*c^3*d*e^3*g), ((5, 5, 3, 1, 2, 1, 0, 1), a^5*b^5*c^3*d*e^2*f*h), ((5, 5, 3, 1, 1, 0, 1, 2), a^5*b^5*c^3*d*e*g*h^2), ((5, 5, 3, 1, 0, 1, 0, 3), a^5*b^5*c^3*d*f*h^3), ((5, 5, 2, 2, 2, 0, 2, 0), a^5*b^5*c^2*d^2*e^2*g^2)]
# testing ((5, 5, 3, 1, 0, 1, 0, 3), a^5*b^5*c^3*d*f*h^3) against a^5*b^5*c^2*d^2*e^2*g^2
# obtaining ordering below 10.0
# a^5*b^5*c^3*d*f*h^3 did not work!
# testing ((5, 5, 3, 1, 2, 1, 0, 1), a^5*b^5*c^3*d*e^2*f*h) against a^5*b^5*c^2*d^2*e^2*g^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^5*c^3*d*e^2*f*h did not work!
# testing ((5, 5, 2, 2, 1, 1, 1, 1), a^5*b^5*c^2*d^2*e*f*g*h) against a^5*b^5*c^2*d^2*e^2*g^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^5*c^2*d^2*e*f*g*h did not work!
# testing ((5, 5, 3, 1, 3, 0, 1, 0), a^5*b^5*c^3*d*e^3*g) against a^5*b^5*c^2*d^2*e^2*g^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^5*c^3*d*e^3*g did not work!
# testing ((5, 5, 3, 1, 1, 0, 1, 2), a^5*b^5*c^3*d*e*g*h^2) against a^5*b^5*c^2*d^2*e^2*g^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^5*c^3*d*e*g*h^2 did not work!
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 33 critical pairs remaining
# 21 polynomials in basis
# current sugar 18
# building (a^4*b^5*c*d^5*e*g, a^5*b^5*c*d^3*e*g, a^5*b^5*c*d^5*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 32 critical pairs remaining
# 21 polynomials in basis
# current sugar 18
# building (a^5*b^5*c*d^3*e*g, a^5*b*d^2*f^2, a^5*b^5*c*d^3*e*f^2*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 31 critical pairs remaining
# 21 polynomials in basis
# current sugar 18
# building (a^4*b^5*c*d^5*e*g, a^4*b^3*d^6, a^4*b^5*c*d^6*e*g)
# new polynomial generated leading monomial with current ordering would be a^4*b^5*c^2*d^5*e^2
# [((5, 4, 2, 3, 2, 0, 2, 0), a^5*b^4*c^2*d^3*e^2*g^2), ((5, 4, 2, 3, 1, 1, 1, 1), a^5*b^4*c^2*d^3*e*f*g*h), ((4, 5, 2, 5, 0, 0, 0, 2), a^4*b^5*c^2*d^5*h^2), ((5, 4, 3, 2, 1, 0, 1, 2), a^5*b^4*c^3*d^2*e*g*h^2), ((5, 4, 3, 2, 0, 1, 0, 3), a^5*b^4*c^3*d^2*f*h^3), ((5, 4, 4, 1, 4, 0, 0, 0), a^5*b^4*c^4*d*e^4), ((5, 4, 4, 1, 2, 0, 0, 2), a^5*b^4*c^4*d*e^2*h^2), ((4, 5, 2, 5, 2, 0, 0, 0), a^4*b^5*c^2*d^5*e^2)]
# testing ((4, 5, 2, 5, 0, 0, 0, 2), a^4*b^5*c^2*d^5*h^2) against a^4*b^5*c^2*d^5*e^2
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^4*b^5*c^2*d^5*h^2 did not work!
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# -----------------------
# current ordering [828, 529, 104, 871, 384, 881, 652, 25]
# 36 critical pairs remaining
# 22 polynomials in basis
# current sugar 18
# building (a^2*b^5*d^10, b^6, a^2*b^6*d^10)
# new polynomial generated leading monomial with current ordering would be a^3*b^5*c*d^7*e*g
# [((3, 5, 1, 7, 0, 1, 0, 1), a^3*b^5*c*d^7*f*h), ((3, 5, 2, 6, 2, 0, 0, 0), a^3*b^5*c^2*d^6*e^2), ((4, 4, 2, 4, 2, 0, 2, 0), a^4*b^4*c^2*d^4*e^2*g^2), ((4, 4, 2, 4, 1, 1, 1, 1), a^4*b^4*c^2*d^4*e*f*g*h), ((3, 5, 2, 6, 0, 0, 0, 2), a^3*b^5*c^2*d^6*h^2), ((5, 3, 3, 1, 3, 2, 1, 0), a^5*b^3*c^3*d*e^3*f^2*g), ((5, 3, 3, 1, 2, 3, 0, 1), a^5*b^3*c^3*d*e^2*f^3*h), ((4, 4, 3, 3, 3, 0, 1, 0), a^4*b^4*c^3*d^3*e^3*g), ((4, 4, 3, 3, 2, 1, 0, 1), a^4*b^4*c^3*d^3*e^2*f*h), ((5, 3, 3, 1, 3, 0, 3, 0), a^5*b^3*c^3*d*e^3*g^3), ((5, 3, 5, 3, 1, 0, 1, 0), a^5*b^3*c^5*d^3*e*g), ((5, 3, 3, 1, 2, 1, 2, 1), a^5*b^3*c^3*d*e^2*f*g^2*h), ((5, 3, 5, 3, 0, 1, 0, 1), a^5*b^3*c^5*d^3*f*h), ((5, 3, 3, 1, 1, 2, 1, 2), a^5*b^3*c^3*d*e*f^2*g*h^2), ((5, 3, 3, 1, 0, 3, 0, 3), a^5*b^3*c^3*d*f^3*h^3), ((5, 3, 4, 0, 4, 2, 0, 0), a^5*b^3*c^4*e^4*f^2), ((4, 4, 3, 3, 1, 0, 1, 2), a^4*b^4*c^3*d^3*e*g*h^2), ((4, 4, 3, 3, 0, 1, 0, 3), a^4*b^4*c^3*d^3*f*h^3), ((4, 4, 4, 2, 4, 0, 0, 0), a^4*b^4*c^4*d^2*e^4), ((5, 3, 4, 0, 4, 0, 2, 0), a^5*b^3*c^4*e^4*g^2), ((5, 3, 6, 2, 2, 0, 0, 0), a^5*b^3*c^6*d^2*e^2), ((5, 3, 4, 0, 3, 1, 1, 1), a^5*b^3*c^4*e^3*f*g*h), ((5, 3, 4, 0, 2, 2, 0, 2), a^5*b^3*c^4*e^2*f^2*h^2), ((4, 4, 4, 2, 2, 0, 0, 2), a^4*b^4*c^4*d^2*e^2*h^2), ((5, 3, 6, 2, 0, 0, 0, 2), a^5*b^3*c^6*d^2*h^2), ((3, 5, 1, 7, 1, 0, 1, 0), a^3*b^5*c*d^7*e*g)]
# testing ((5, 3, 4, 0, 4, 2, 0, 0), a^5*b^3*c^4*e^4*f^2) against a^3*b^5*c*d^7*e*g
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^3*c^4*e^4*f^2 did not work!
# testing ((5, 3, 4, 0, 2, 2, 0, 2), a^5*b^3*c^4*e^2*f^2*h^2) against a^3*b^5*c*d^7*e*g
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^3*c^4*e^2*f^2*h^2 did not work!
# testing ((5, 3, 3, 1, 3, 2, 1, 0), a^5*b^3*c^3*d*e^3*f^2*g) against a^3*b^5*c*d^7*e*g
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# obtaining ordering below 101.0
# 37 constraints
# a^5*b^3*c^3*d*e^3*f^2*g worked! with ((5, 3, 3, 1, 3, 2, 1, 0), [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0], Linear Program (minimization, 8 variables, 37 constraints))
# boundaries set([(0.01, 0.01, 0.01, 0.1878571421759469, 0.3407142843518938, 0.21785714217594687, 0.1828571421759469, 0.29571428435189384), (0.01, 0.42499999841054265, 0.01, 0.01, 0.19249999920527133, 0.24749999920527133, 0.21249999920527138, 0.1474999992052715), (0.01, 0.3399999980926516, 0.24499999904632574, 0.07999999999999995, 0.05500000000000005, 0.2749999990463257, 0.23999999904632574, 0.01), (0.4939999980926514, 0.01, 0.01, 0.2569999990463257, 0.23699999904632568, 0.04499999999999996, 0.01, 0.19199999904632567), (0.01, 0.01, 0.01, 0.24499999904632563, 0.321666665395101, 0.4083333317438761, 0.23999999904632566, 0.01)])
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 41 critical pairs remaining
# 23 polynomials in basis
# current sugar 18
# building (a^2*b^5*d^10, a^3*b^4*d^8, a^3*b^5*d^10)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 40 critical pairs remaining
# 23 polynomials in basis
# current sugar 19
# building (a^5*b^5*c*d^3*e*g, a^2*b^5*c^4, a^5*b^5*c^4*d^3*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 39 critical pairs remaining
# 23 polynomials in basis
# current sugar 19
# building (a^3*b^4*c^8, a*b*d^2*f^2, a^3*b^4*c^8*d^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 38 critical pairs remaining
# 23 polynomials in basis
# current sugar 19
# building (a^4*b^3*d^6, a^2*b^5*c^4, a^4*b^5*c^4*d^6)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^5*d^3*e*g
# [((5, 4, 5, 3, 1, 0, 1, 0), a^5*b^4*c^5*d^3*e*g)]
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 42 critical pairs remaining
# 24 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^3*e*f*h, b^6, a^5*b^6*c^2*d^3*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 41 critical pairs remaining
# 24 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^2*e^2*g^2, b^6, a^5*b^6*c^2*d^2*e^2*g^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 40 critical pairs remaining
# 24 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^3*e*f*h, a^6, a^6*b^5*c^2*d^3*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 39 critical pairs remaining
# 24 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^2*e^2*g^2, a^6, a^6*b^5*c^2*d^2*e^2*g^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 38 critical pairs remaining
# 24 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^3*e*f*h, a^5*b^5*c*d^3*e*g, a^5*b^5*c^2*d^3*e*f*g*h)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e^3*g
# [((5, 5, 3, 2, 3, 0, 1, 0), a^5*b^5*c^3*d^2*e^3*g)]
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 43 critical pairs remaining
# 25 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^3*e*f*h, a^5*b^2*d^4, a^5*b^5*c^2*d^4*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 42 critical pairs remaining
# 25 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^2*e^2*g^2, a^5*b^5*c*d^3*e*g, a^5*b^5*c^2*d^3*e^2*g^2)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e^2*f*h
# [((5, 5, 3, 2, 2, 1, 0, 1), a^5*b^5*c^3*d^2*e^2*f*h)]
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 48 critical pairs remaining
# 26 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^3*e*f*h, a^5*b^5*c^2*d^3*e^2, a^5*b^5*c^2*d^3*e^2*f*h)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e^4
# [((5, 5, 3, 2, 4, 0, 0, 0), a^5*b^5*c^3*d^2*e^4)]
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 54 critical pairs remaining
# 27 polynomials in basis
# current sugar 19
# building (a^4*b^5*c^2*d^5*e^2, b^6, a^4*b^6*c^2*d^5*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 53 critical pairs remaining
# 27 polynomials in basis
# current sugar 19
# building (a^4*b^5*c^2*d^5*e^2, a^5*b^5*c^2*d^3*e^2, a^5*b^5*c^2*d^5*e^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 52 critical pairs remaining
# 27 polynomials in basis
# current sugar 19
# building (a^5*b^5*c^2*d^3*e*f*h, a^5*b*d^2*f^2, a^5*b^5*c^2*d^3*e*f^2*h)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e^3*f
# [((5, 5, 3, 2, 3, 1, 0, 0), a^5*b^5*c^3*d^2*e^3*f)]
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# -----------------------
# current ordering [2.0, 1.0, 1.0, 5.0, 6.0, 8.0, 4.0, 1.0]
# 56 critical pairs remaining
# 28 polynomials in basis
# current sugar 19
# building (a^4*b^5*c^2*d^5*e^2, a^4*b^5*c*d^5*e*g, a^4*b^5*c^2*d^5*e^2*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^2*d^3*e^2*g^3
# [((4, 5, 2, 5, 1, 1, 0, 1), a^4*b^5*c^2*d^5*e*f*h), ((5, 4, 2, 3, 2, 0, 3, 0), a^5*b^4*c^2*d^3*e^2*g^3)]
# testing ((4, 5, 2, 5, 1, 1, 0, 1), a^4*b^5*c^2*d^5*e*f*h) against a^5*b^4*c^2*d^3*e^2*g^3
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# 38 constraints
# a^4*b^5*c^2*d^5*e*f*h worked! with ((4, 5, 2, 5, 1, 1, 0, 1), [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0], Linear Program (minimization, 8 variables, 38 constraints))
# boundaries set([(0.01, 0.4424999980131784, 0.01, 0.01, 0.1962499990065893, 0.2612499990065892, 0.21624999900658928, 0.1412499990065895), (0.01, 0.01, 0.01, 0.2618023243338563, 0.34406976577847515, 0.43633720722309377, 0.20529069670411046, 0.01), (0.5009999976158143, 0.01, 0.01, 0.26549999880790714, 0.24549999880790732, 0.05499999999999977, 0.01, 0.19049999880790733), (0.01, 0.32499999761581466, 0.2524999988079071, 0.09499999999999985, 0.06499999999999995, 0.2874999988079072, 0.24249999880790718, 0.01), (0.01, 0.01, 0.01, 0.19535714200564805, 0.3507142840112961, 0.23035714200564802, 0.18535714200564804, 0.2957142840112961)])
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 62 critical pairs remaining
# 29 polynomials in basis
# current sugar 19
# building (a^4*b^5*c^2*d^5*e^2, a^4*b^3*d^6, a^4*b^5*c^2*d^6*e^2)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^3*d^3*e^3*g
# [((5, 4, 3, 3, 3, 0, 1, 0), a^5*b^4*c^3*d^3*e^3*g)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 66 critical pairs remaining
# 30 polynomials in basis
# current sugar 19
# building (a^5*b^3*c^3*d*e^3*f^2*g, a^6, a^6*b^3*c^3*d*e^3*f^2*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 65 critical pairs remaining
# 30 polynomials in basis
# current sugar 19
# building (a^5*b^3*c^3*d*e^3*f^2*g, a^5*b*d^2*f^2, a^5*b^3*c^3*d^2*e^3*f^2*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^3*c^4*d*e^4*f^2
# [((5, 3, 4, 1, 4, 2, 0, 0), a^5*b^3*c^4*d*e^4*f^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 70 critical pairs remaining
# 31 polynomials in basis
# current sugar 19
# building (a^4*b^5*c*d^5*e*g, a*b*d^2*f^2, a^4*b^5*c*d^5*e*f^2*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 69 critical pairs remaining
# 31 polynomials in basis
# current sugar 19
# building (a^2*b^5*d^10, a*b*d^2*f^2, a^2*b^5*d^10*f^2)
# new polynomial generated leading monomial with current ordering would be a^5*b^2*c^3*d*e^3*f^4*g
# [((5, 2, 3, 1, 3, 4, 1, 0), a^5*b^2*c^3*d*e^3*f^4*g)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 71 critical pairs remaining
# 32 polynomials in basis
# current sugar 20
# building (a^4*b^3*c^12, a^3*b^4*c^8, a^4*b^4*c^12)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 70 critical pairs remaining
# 32 polynomials in basis
# current sugar 20
# building (a^5*b^4*c^5*d^3*e*g, a^5*b^5*c*d^3*e*g, a^5*b^5*c^5*d^3*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 69 critical pairs remaining
# 32 polynomials in basis
# current sugar 20
# building (a^5*b^4*c^5*d^3*e*g, a^6, a^6*b^4*c^5*d^3*e*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 68 critical pairs remaining
# 32 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^2*d^2*e^2*g^2, a^2*b^5*c^4, a^5*b^5*c^4*d^2*e^2*g^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 67 critical pairs remaining
# 32 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^2*d^3*e*f*h, a^2*b^5*c^4, a^5*b^5*c^4*d^3*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 66 critical pairs remaining
# 32 polynomials in basis
# current sugar 20
# building (a^5*b^4*c^5*d^3*e*g, a^5*b^2*d^4, a^5*b^4*c^5*d^4*e*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^6*d^3*e^2
# [((5, 4, 6, 3, 2, 0, 0, 0), a^5*b^4*c^6*d^3*e^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 71 critical pairs remaining
# 33 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^2*f*h, a^2*b^5*c^4, a^5*b^5*c^4*d^2*e^2*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 70 critical pairs remaining
# 33 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^2*f*h, b^6, a^5*b^6*c^3*d^2*e^2*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 69 critical pairs remaining
# 33 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*g, a^2*b^5*c^4, a^5*b^5*c^4*d^2*e^3*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 68 critical pairs remaining
# 33 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*g, b^6, a^5*b^6*c^3*d^2*e^3*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 67 critical pairs remaining
# 33 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^2*f*h, a^6, a^6*b^5*c^3*d^2*e^2*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 66 critical pairs remaining
# 33 polynomials in basis
# current sugar 20
# building (a^4*b^5*c*d^5*e*g, a^2*b^5*c^4, a^4*b^5*c^4*d^5*e*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^5*d^2*e^2*g^2
# [((5, 4, 5, 2, 2, 0, 2, 0), a^5*b^4*c^5*d^2*e^2*g^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 70 critical pairs remaining
# 34 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*g, a^6, a^6*b^5*c^3*d^2*e^3*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 69 critical pairs remaining
# 34 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*g, a^5*b^5*c^2*d^2*e^2*g^2, a^5*b^5*c^3*d^2*e^3*g^2)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e*g^2*h^2
# [((5, 5, 3, 2, 1, 0, 2, 2), a^5*b^5*c^3*d^2*e*g^2*h^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 74 critical pairs remaining
# 35 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^4, a^2*b^5*c^4, a^5*b^5*c^4*d^2*e^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 73 critical pairs remaining
# 35 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^4, b^6, a^5*b^6*c^3*d^2*e^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 72 critical pairs remaining
# 35 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^2*f*h, a^5*b^5*c^2*d^3*e*f*h, a^5*b^5*c^3*d^3*e^2*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 71 critical pairs remaining
# 35 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e^2, a^2*b^5*c^4, a^4*b^5*c^4*d^5*e^2)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^4*d^3*e^2*g^2
# [((5, 4, 4, 3, 2, 0, 2, 0), a^5*b^4*c^4*d^3*e^2*g^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 76 critical pairs remaining
# 36 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^5*b^5*c^3*d^2*e^2*f*h, a^5*b^5*c^3*d^2*e^3*f*h)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e^2*g*h^2
# [((5, 5, 3, 2, 2, 0, 1, 2), a^5*b^5*c^3*d^2*e^2*g*h^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 82 critical pairs remaining
# 37 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*g, a^5*b^5*c*d^3*e*g, a^5*b^5*c^3*d^3*e^3*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 81 critical pairs remaining
# 37 polynomials in basis
# current sugar 20
# building (a^5*b^4*c^3*d^3*e^3*g, a^5*b^5*c^3*d^2*e^3*g, a^5*b^5*c^3*d^3*e^3*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 80 critical pairs remaining
# 37 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^2*b^5*c^4, a^5*b^5*c^4*d^2*e^3*f)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 79 critical pairs remaining
# 37 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, b^6, a^5*b^6*c^3*d^2*e^3*f)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 78 critical pairs remaining
# 37 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^4, a^6, a^6*b^5*c^3*d^2*e^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 77 critical pairs remaining
# 37 polynomials in basis
# current sugar 20
# building (a^3*b^4*d^8, a^2*b^5*c^4, a^3*b^5*c^4*d^8)
# new polynomial generated leading monomial with current ordering would be a^4*b^4*c^5*d^5*e*g
# [((4, 4, 5, 5, 1, 0, 1, 0), a^4*b^4*c^5*d^5*e*g)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 81 critical pairs remaining
# 38 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e*f*h, b^6, a^4*b^6*c^2*d^5*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 80 critical pairs remaining
# 38 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^4, a^5*b^5*c^3*d^2*e^3*g, a^5*b^5*c^3*d^2*e^4*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 79 critical pairs remaining
# 38 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^2*f*h, a^2*b^5*c^3*d^2*f^2, a^5*b^5*c^3*d^2*e^2*f^2*h)
# new polynomial generated leading monomial with current ordering would be a^5*b^5*c^3*d^2*e*f*g*h^2
# [((5, 5, 3, 2, 1, 1, 1, 2), a^5*b^5*c^3*d^2*e*f*g*h^2)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 84 critical pairs remaining
# 39 polynomials in basis
# current sugar 20
# building (a^5*b^4*c^3*d^3*e^3*g, a^6, a^6*b^4*c^3*d^3*e^3*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 83 critical pairs remaining
# 39 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^6, a^6*b^5*c^3*d^2*e^3*f)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 82 critical pairs remaining
# 39 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e*f*h, a^5*b^5*c^2*d^3*e*f*h, a^5*b^5*c^2*d^5*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 81 critical pairs remaining
# 39 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^5*b^5*c^3*d^2*e^3*g, a^5*b^5*c^3*d^2*e^3*f*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 80 critical pairs remaining
# 39 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^4, a^5*b^5*c^2*d^3*e^2, a^5*b^5*c^3*d^3*e^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 79 critical pairs remaining
# 39 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e*f*h, a^4*b^5*c*d^5*e*g, a^4*b^5*c^2*d^5*e*f*g*h)
# new polynomial generated leading monomial with current ordering would be a^4*b^5*c^3*d^4*e^3*g
# [((4, 5, 3, 4, 3, 0, 1, 0), a^4*b^5*c^3*d^4*e^3*g)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 83 critical pairs remaining
# 40 polynomials in basis
# current sugar 20
# building (a^5*b^4*c^3*d^3*e^3*g, a^5*b^2*d^4, a^5*b^4*c^3*d^4*e^3*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^4*c^4*d^3*e^4
# [((5, 4, 4, 3, 4, 0, 0, 0), a^5*b^4*c^4*d^3*e^4)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 88 critical pairs remaining
# 41 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^5*b^5*c^2*d^3*e^2, a^5*b^5*c^3*d^3*e^3*f)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 87 critical pairs remaining
# 41 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e*f*h, a^4*b^3*d^6, a^4*b^5*c^2*d^6*e*f*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 86 critical pairs remaining
# 41 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^5*b^5*c^3*d^2*e^4, a^5*b^5*c^3*d^2*e^4*f)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 85 critical pairs remaining
# 41 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e*f*h, a^4*b^5*c^2*d^5*e^2, a^4*b^5*c^2*d^5*e^2*f*h)
# new polynomial generated leading monomial with current ordering would be a^4*b^5*c^3*d^4*e^4
# [((4, 5, 3, 4, 4, 0, 0, 0), a^4*b^5*c^3*d^4*e^4)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 90 critical pairs remaining
# 42 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^2*d^2*e^2*g^2, a^5*b*d^2*f^2, a^5*b^5*c^2*d^2*e^2*f^2*g^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 89 critical pairs remaining
# 42 polynomials in basis
# current sugar 20
# building (a^5*b^5*c^3*d^2*e^3*f, a^2*b^5*c^3*d^2*f^2, a^5*b^5*c^3*d^2*e^3*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 88 critical pairs remaining
# 42 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e*f*h, a*b*d^2*f^2, a^4*b^5*c^2*d^5*e*f^2*h)
# new polynomial generated leading monomial with current ordering would be a^4*b^5*c^3*d^4*e^3*f
# [((5, 4, 2, 3, 2, 1, 3, 0), a^5*b^4*c^2*d^3*e^2*f*g^3), ((4, 5, 3, 4, 3, 1, 0, 0), a^4*b^5*c^3*d^4*e^3*f)]
# testing ((5, 4, 2, 3, 2, 1, 3, 0), a^5*b^4*c^2*d^3*e^2*f*g^3) against a^4*b^5*c^3*d^4*e^3*f
# obtaining ordering below 1.0
# failed
# obtaining ordering below 101.0
# a^5*b^4*c^2*d^3*e^2*f*g^3 did not work!
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 92 critical pairs remaining
# 43 polynomials in basis
# current sugar 20
# building (a^5*b^3*c^4*d*e^4*f^2, a^6, a^6*b^3*c^4*d*e^4*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 91 critical pairs remaining
# 43 polynomials in basis
# current sugar 20
# building (a^5*b^3*c^4*d*e^4*f^2, a^5*b^3*c^3*d*e^3*f^2*g, a^5*b^3*c^4*d*e^4*f^2*g)
# new polynomial generated leading monomial with current ordering would be a^5*b^3*c^4*d*e^3*f^3*h
# [((3, 5, 2, 7, 2, 0, 1, 0), a^3*b^5*c^2*d^7*e^2*g), ((5, 3, 4, 1, 3, 3, 0, 1), a^5*b^3*c^4*d*e^3*f^3*h)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 97 critical pairs remaining
# 44 polynomials in basis
# current sugar 20
# building (a^5*b^3*c^4*d*e^4*f^2, a^5*b*d^2*f^2, a^5*b^3*c^4*d^2*e^4*f^2)
# new polynomial generated leading monomial with current ordering would be a^4*b^4*c^3*d^5*e^3*g
# [((4, 4, 3, 5, 3, 0, 1, 0), a^4*b^4*c^3*d^5*e^3*g)]
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 101 critical pairs remaining
# 45 polynomials in basis
# current sugar 20
# building (a^4*b^5*c^2*d^5*e^2, a*b*d^2*f^2, a^4*b^5*c^2*d^5*e^2*f^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [3.0, 1.0, 1.0, 6.0, 7.0, 9.0, 4.0, 1.0]
# 100 critical pairs remaining
# 45 polynomials in basis
# current sugar 20
# building (a^5*b^2*c^3*d*e^3*f^4*g, a^5*b^3*c^3*d*e^3*f^2*g, a^5*b^3*c^3*d*e^3*f^4*g)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# ...
# building (a^5*b^2*c^11*d^2*e^4*g^4*h^2, a^5*b^2*c^11*d^2*e^4*g^6, a^5*b^2*c^11*d^2*e^4*g^6*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 527 critical pairs remaining
# 783 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^9*d^4*e^4*g^3*h^4, a^4*b^3*c^9*d^4*e^4*g^4, a^4*b^3*c^9*d^4*e^4*g^4*h^4)
# new polynomial generated leading monomial with current ordering would be a^4*b^3*c^10*d^3*e^4*f*g^2*h^5
# [((4, 3, 10, 3, 4, 1, 2, 5), a^4*b^3*c^10*d^3*e^4*f*g^2*h^5)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 532 critical pairs remaining
# 784 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d^2*e^3*f*g^3*h^4, a^5*b^2*c^12*d^2*e^3*g^3*h^3, a^5*b^2*c^12*d^2*e^3*f*g^3*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 531 critical pairs remaining
# 784 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^9*d^4*e^4*g^3*h^4, a^4*b^4*c^7*d^3*e^4*g^3*h^4, a^4*b^4*c^9*d^4*e^4*g^3*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 530 critical pairs remaining
# 784 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d^2*e^3*f*g^4*h^3, a^5*b^2*c^12*d^2*e^3*g^3*h^3, a^5*b^2*c^12*d^2*e^3*f*g^4*h^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 529 critical pairs remaining
# 784 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d^2*e^3*f*g^5*h^2, a^5*b^2*c^12*d^2*e^3*g^4*h^2, a^5*b^2*c^12*d^2*e^3*f*g^5*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 528 critical pairs remaining
# 784 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^10*d^4*e^3*f*g^2*h^4, a^4*b^3*c^10*d^4*e^3*f*g^3*h, a^4*b^3*c^10*d^4*e^3*f*g^3*h^4)
# new polynomial generated leading monomial with current ordering would be a^5*b^2*c^10*d^2*e^4*g^6*h^3
# [((5, 2, 10, 2, 4, 0, 6, 3), a^5*b^2*c^10*d^2*e^4*g^6*h^3)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 533 critical pairs remaining
# 785 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^9*d^4*e^3*f*g^3*h^4, a^4*b^3*c^10*d^4*e^3*f*g^2*h^4, a^4*b^3*c^10*d^4*e^3*f*g^3*h^4)
# new polynomial generated leading monomial with current ordering would be a^4*b^3*c^11*d^3*e^3*g^3*h^5
# [((4, 3, 11, 3, 3, 0, 3, 5), a^4*b^3*c^11*d^3*e^3*g^3*h^5)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 539 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^10*d^4*e^3*f*g^2*h^4, a^4*b^4*c^6*d^4*e^3*f*g^2*h^4, a^4*b^4*c^10*d^4*e^3*f*g^2*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 538 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^11*d^4*e^2*f*g*h^5, a*b*d^2*f^2, a^4*b^3*c^11*d^4*e^2*f^2*g*h^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 537 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^11*d^4*e^2*f*g^2*h^4, a*b*d^2*f^2, a^4*b^3*c^11*d^4*e^2*f^2*g^2*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 536 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^11*d^3*e^5*g^3*h^2, a^4*b^3*c^12, a^4*b^3*c^12*d^3*e^5*g^3*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 535 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^11*d^3*e^5*g^5, a^4*b^3*c^12, a^4*b^3*c^12*d^3*e^5*g^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 534 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*f*g^3*h^5, a^5*b^2*c^10*d^3*e^2*f*g^4*h, a^5*b^2*c^10*d^3*e^2*f*g^4*h^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 533 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*f*g^3*h^5, a^5*b^3*c^6*d^3*e^2*f*g^3*h^5, a^5*b^3*c^10*d^3*e^2*f*g^3*h^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 532 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*g^5*h^4, a^5*b^2*c^10*d^3*e^2*f*g^4*h, a^5*b^2*c^10*d^3*e^2*f*g^5*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 531 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*g^6*h^3, a^5*b^2*c^10*d^3*e^2*f*g^4*h, a^5*b^2*c^10*d^3*e^2*f*g^6*h^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 530 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*g^7*h^2, a^5*b^2*c^10*d^3*e^2*f*g^4*h, a^5*b^2*c^10*d^3*e^2*f*g^7*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 529 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^3*c^7*e^7*f*g^7*h, a^5*b^4*c^6*e^6*f*g^2, a^5*b^4*c^7*e^7*f*g^7*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 528 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^9*d^4*e^4*g^3*h^4, a^4*b^3*c^10*d^4*e^4, a^4*b^3*c^10*d^4*e^4*g^3*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 527 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^11*d^4*e^2*f*g*h^5, a^4*b^3*c^11*d^4*e^3*f, a^4*b^3*c^11*d^4*e^3*f*g*h^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 526 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^11*d^4*e^2*f*g^2*h^4, a^4*b^3*c^11*d^4*e^3*f, a^4*b^3*c^11*d^4*e^3*f*g^2*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 525 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^4*b^3*c^10*d^4*e^3*f*g^2*h^4, a^4*b^3*c^11*d^4*e^2*f*g^2*h^4, a^4*b^3*c^11*d^4*e^3*f*g^2*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 524 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^12*e^7*g^3*h^2, a^5*b^3*c^9*e^7*g^2*h^2, a^5*b^3*c^12*e^7*g^3*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 523 critical pairs remaining
# 786 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^15*d*e^5*h^3, a^5*b^2*c^15*d*e^4*g*h^2, a^5*b^2*c^15*d*e^5*g*h^3)
# new polynomial generated leading monomial with current ordering would be a^5*b^2*c^10*d^2*e^3*f*g^5*h^4
# [((5, 2, 10, 2, 3, 1, 5, 4), a^5*b^2*c^10*d^2*e^3*f*g^5*h^4)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 528 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^15*d*e^5*h^3, a^4*b^3*c^12, a^5*b^3*c^15*d*e^5*h^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 527 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*g^5*h^4, a^5*b^2*c^9*d^3*e^3*g^5, a^5*b^2*c^10*d^3*e^3*g^5*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 526 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*g^6*h^3, a^5*b^2*c^9*d^3*e^3*g^5, a^5*b^2*c^10*d^3*e^3*g^6*h^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 525 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*g^7*h^2, a^5*b^2*c^9*d^3*e^3*g^5, a^5*b^2*c^10*d^3*e^3*g^7*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 524 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^10*d^3*e^2*f*g^3*h^5, a^5*b^2*c^11*d^3*e^2*f*g^3, a^5*b^2*c^11*d^3*e^2*f*g^3*h^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 523 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^3*c^10*d*e^2*f^3*g^2*h^5, a^5*b^3*c^9*d^2*e^2*f*g*h^3, a^5*b^3*c^10*d^2*e^2*f^3*g^2*h^5)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 522 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^3*c^7*e^7*f*g^7*h, a^5*b^3*c^8*e^7*g^5*h, a^5*b^3*c^8*e^7*f*g^7*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 521 critical pairs remaining
# 787 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d*e^5*f*g^4*h^2, a^5*b^2*c^11*d*e^5*f*g^3*h^3, a^5*b^2*c^11*d*e^5*f*g^4*h^3)
# new polynomial generated leading monomial with current ordering would be a^4*b^3*c^10*d^4*e^3*g^4*h^4
# [((4, 3, 10, 4, 3, 0, 4, 4), a^4*b^3*c^10*d^4*e^3*g^4*h^4)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 526 critical pairs remaining
# 788 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d*e^5*f*g^3*h^3, a^5*b^3*c^11*e^5*f*g^2*h^3, a^5*b^3*c^11*d*e^5*f*g^3*h^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 525 critical pairs remaining
# 788 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d*e^5*f*g^4*h^2, a^5*b^2*c^11*d*e^5*f*g^5*h, a^5*b^2*c^11*d*e^5*f*g^5*h^2)
# new polynomial generated leading monomial with current ordering would be a^5*b^2*c^12*e^7*g^5*h
# [((5, 2, 12, 0, 7, 0, 5, 1), a^5*b^2*c^12*e^7*g^5*h)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 531 critical pairs remaining
# 789 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d*e^5*f*g^4*h^2, a^5*b^3*c^11*e^5*f*g^3*h^2, a^5*b^3*c^11*d*e^5*f*g^4*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 530 critical pairs remaining
# 789 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^11*d*e^5*f*g^5*h, a^5*b^3*c^8*d*e^5*f*g^5, a^5*b^3*c^11*d*e^5*f*g^5*h)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 529 critical pairs remaining
# 789 polynomials in basis
# current sugar 32
# building (a^5*b^3*c^11*e^4*f^3*h^5, a^5*b^3*c^11*e^4*f^4*h^3, a^5*b^3*c^11*e^4*f^4*h^5)
# new polynomial generated leading monomial with current ordering would be a^5*b^3*c^11*e^4*f^2*g^2*h^5
# [((5, 3, 11, 0, 4, 2, 2, 5), a^5*b^3*c^11*e^4*f^2*g^2*h^5)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 534 critical pairs remaining
# 790 polynomials in basis
# current sugar 32
# building (a^5*b^3*c^11*e^4*f^3*g*h^4, a^5*b^3*c^11*e^4*f^4*h^3, a^5*b^3*c^11*e^4*f^4*g*h^4)
# new polynomial generated leading monomial with current ordering would be a^5*b^3*c^10*d*e*f^6*h^6
# [((5, 3, 10, 1, 1, 6, 0, 6), a^5*b^3*c^10*d*e*f^6*h^6)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 538 critical pairs remaining
# 791 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^15*d*e^2*f^2*h^4, a^5*b^2*c^15*d^2*e^2*f*h, a^5*b^2*c^15*d^2*e^2*f^2*h^4)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 537 critical pairs remaining
# 791 polynomials in basis
# current sugar 32
# building (a^5*b^3*c^11*e^4*f^3*g^2*h^3, a^5*b^3*c^11*e^4*f^4*h^3, a^5*b^3*c^11*e^4*f^4*g^2*h^3)
# new polynomial generated leading monomial with current ordering would be a^5*b^3*c^10*d*e*f^6*g*h^5
# [((5, 3, 10, 1, 1, 6, 1, 5), a^5*b^3*c^10*d*e*f^6*g*h^5)]
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 542 critical pairs remaining
# 792 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^13*e^7*g^2*h^2, a^5*b^2*c^13*e^7*g^3, a^5*b^2*c^13*e^7*g^3*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 541 critical pairs remaining
# 792 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^12*e^7*g^3*h^2, a^5*b^2*c^13*e^7*g^2*h^2, a^5*b^2*c^13*e^7*g^3*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 540 critical pairs remaining
# 792 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^13*e^7*g^2*h^2, a^5*b^3*c^9*e^7*g^2*h^2, a^5*b^3*c^13*e^7*g^2*h^2)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 539 critical pairs remaining
# 792 polynomials in basis
# current sugar 32
# building (a^5*b^2*c^15*d*e^5*h^3, a^5*b^2*c^16, a^5*b^2*c^16*d*e^5*h^3)
# new polynomial generated leading monomial with current ordering would be 0
# -----------------------
# current ordering [98.0, 1.0, 8.0, 57.0, 39.0, 33.0, 1.0, 1.0]
# 538 critical pairs remaining
# 792 polynomials in basis
